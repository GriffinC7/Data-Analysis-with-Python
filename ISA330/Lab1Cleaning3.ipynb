# %%
import pandas as pd
import numpy as np

# %%
data = pd.read_csv("AboutUS.csv")
print(data.shape)
print(data.columns)
data.head()
# Out:
# (34, 24)
# Index(['StartDate', 'EndDate', 'Status', 'IPAddress', 'Progress',
#        'Duration (in seconds)', 'Finished', 'RecordedDate', 'ResponseId',
#        'RecipientLastName', 'RecipientFirstName', 'RecipientEmail',
#        'ExternalReference', 'LocationLatitude', 'LocationLongitude',
#        'DistributionChannel', 'UserLanguage', 'Q1', 'Q2', 'Q3', 'Q5', 'Q6',
#        'Q7', 'Q8'],
#       dtype='object')
#                                            StartDate  \
# 0                                         Start Date
# 1  {"ImportId":"startDate","timeZone":"America/De...
# 2                                2022-09-07 09:56:08
# 3                                2022-09-07 10:00:02
# 4                                2022-09-07 10:01:16
#
#                                              EndDate                 Status  \
# 0                                           End Date          Response Type
# 1  {"ImportId":"endDate","timeZone":"America/Denv...  {"ImportId":"status"}
# ...

# %%
data = data[['Duration (in seconds)', 'RecordedDate', 'Q1', 'Q2', 'Q3', 'Q5', 'Q6','Q7', 'Q8']]
print(data.shape)
data.head()
# Out:
# (34, 9)
#      Duration (in seconds)                                       RecordedDate  \
# 0    Duration (in seconds)                                      Recorded Date
# 1  {"ImportId":"duration"}  {"ImportId":"recordedDate","timeZone":"America...
# 2                       36                                2022-09-07 09:56:46
# 3                        8                                2022-09-07 10:00:10
# 4                        9                                2022-09-07 10:01:26
#
#                          Q1                        Q2                   Q3  \
# 0                      Name           Favorite Number                 Pet?
# 1  {"ImportId":"QID1_TEXT"}  {"ImportId":"QID2_TEXT"}  {"ImportId":"QID3"}
# 2                   Testing                       NaN                  NaN
# 3                  Testing2                       NaN                  NaN
# 4                  Testing3                         3                  NaN
#
# ...

# %%
data2 = data.drop([0,1,2,3,4,9])
data2.head()
# Out:
#    Duration (in seconds)         RecordedDate                     Q1  Q2   Q3  \
# 5                     30  2022-09-07 10:18:07         Emma Pedolzky   13  Yes
# 6                     51  2022-09-07 10:19:01        Emma Pedolzky    13  Yes
# 7                     91  2022-09-07 11:01:09  Norberto Alvarado III   6  Yes
# 8                    286  2022-09-07 11:02:22     Trevor Christensen   3  Yes
# 10                    59  2022-09-07 11:03:00                   Nick   9  Yes
#
#                  Q5        Q6           Q7         Q8
# 5               Dog  May 2025  Second year  5 ft 8 in
# 6               Dog  May 2025  Second year    5ft 8in
# 7               Dog   05/2023  Fourth year        5'7
# 8               Dog  May 2025  Second year      5'9''
# 10  Dog,Cat,Reptile  May 2023  Fourth year          6

# %%
print(data2.shape)
data3 = data2.drop_duplicates(subset=['Q1'], keep = 'last')
print(data3.shape)
#df.drop_duplicates(subset=['brand'])
# Out:
# (28, 9)
# (25, 9)

# %%
data3
# Out:
#    Duration (in seconds)         RecordedDate                     Q1    Q2  \
# 5                     30  2022-09-07 10:18:07         Emma Pedolzky     13
# 6                     51  2022-09-07 10:19:01        Emma Pedolzky      13
# 7                     91  2022-09-07 11:01:09  Norberto Alvarado III     6
# 8                    286  2022-09-07 11:02:22     Trevor Christensen     3
# 10                    59  2022-09-07 11:03:00                   Nick     9
# 11                   231  2022-09-07 11:23:38            Renee Delos    11
# 12                    75  2022-09-07 18:40:58           Katelyn Muia    44
# 13                    88  2022-09-07 18:57:05      Darya Bankouskaya     4
# 15                   187  2022-09-07 20:40:48                Griffin     7
# 16                    30  2022-09-08 09:04:27       Reese Stevenson    343
# 17                    83  2022-09-08 11:22:33           Jack Sweeney     7
# ...

# %%
data3["Q1"][5]
# Out:
# 'Emma Pedolzky '

# %%
data3["Q1"][6]
# Out:
# 'Emma Pedolzky  '

# %%
newnames = []
for name in data3["Q1"]:
    newnames.append(name.strip())
print(newnames)
# Out:
# ['Emma Pedolzky', 'Emma Pedolzky', 'Norberto Alvarado III', 'Trevor Christensen', 'Nick', 'Renee Delos', 'Katelyn Muia', 'Darya Bankouskaya', 'Griffin', 'Reese Stevenson', 'Jack Sweeney', 'Peter Sullivan', 'Ian James Carpenter', 'Luke Walsh', 'Adam', 'Jon Riordan', 'ML Tlachac', 'Luke Lamontagne', 'Ganesh Thammana', 'Thomas', 'Fadi Oumera', 'Trevor Francis', 'Natalia Kuipers', 'Matthew Bilan', 'Luis']

# %%
data3["Q1"] = newnames
#could call new columns 'names' and then drop Q1
data3.head()
# Out:
# C:\Users\mltlachac\AppData\Local\Temp\ipykernel_9280\1005319741.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data3["Q1"] = newnames
#    Duration (in seconds)         RecordedDate                     Q1  Q2   Q3  \
# 5                     30  2022-09-07 10:18:07          Emma Pedolzky  13  Yes
# 6                     51  2022-09-07 10:19:01          Emma Pedolzky  13  Yes
# 7                     91  2022-09-07 11:01:09  Norberto Alvarado III   6  Yes
# 8                    286  2022-09-07 11:02:22     Trevor Christensen   3  Yes
# 10                    59  2022-09-07 11:03:00                   Nick   9  Yes
#
#                  Q5        Q6           Q7         Q8
# 5               Dog  May 2025  Second year  5 ft 8 in
# ...

# %%
print(data3.shape)
data3 = data3.drop_duplicates(subset=['Q1'], keep = 'last')
print(data3.shape)
# Out:
# (25, 9)
# (24, 9)

# %%
data3.head()
# Out:
#    Duration (in seconds)         RecordedDate                     Q1  Q2   Q3  \
# 6                     51  2022-09-07 10:19:01          Emma Pedolzky  13  Yes
# 7                     91  2022-09-07 11:01:09  Norberto Alvarado III   6  Yes
# 8                    286  2022-09-07 11:02:22     Trevor Christensen   3  Yes
# 10                    59  2022-09-07 11:03:00                   Nick   9  Yes
# 11                   231  2022-09-07 11:23:38            Renee Delos  11  Yes
#
#                  Q5        Q6           Q7       Q8
# 6               Dog  May 2025  Second year  5ft 8in
# 7               Dog   05/2023  Fourth year      5'7
# 8               Dog  May 2025  Second year    5'9''
# 10  Dog,Cat,Reptile  May 2023  Fourth year        6
# 11              Dog      2024   Third year  5.66 ft

# %%
df = data3.reset_index(drop = True)
df.head()
# Out:
#   Duration (in seconds)         RecordedDate                     Q1  Q2   Q3  \
# 0                    51  2022-09-07 10:19:01          Emma Pedolzky  13  Yes
# 1                    91  2022-09-07 11:01:09  Norberto Alvarado III   6  Yes
# 2                   286  2022-09-07 11:02:22     Trevor Christensen   3  Yes
# 3                    59  2022-09-07 11:03:00                   Nick   9  Yes
# 4                   231  2022-09-07 11:23:38            Renee Delos  11  Yes
#
#                 Q5        Q6           Q7       Q8
# 0              Dog  May 2025  Second year  5ft 8in
# 1              Dog   05/2023  Fourth year      5'7
# 2              Dog  May 2025  Second year    5'9''
# 3  Dog,Cat,Reptile  May 2023  Fourth year        6
# 4              Dog      2024   Third year  5.66 ft

# %% [markdown]
# # Assignment
#
# * Clean the notebooks for last class and this class - comments, print statements, markdown explanations
# * Run Friday class code on both the uncleaned and the cleaned dataset

# %%
#rename columns
#saving the dataset
#categorize animlas
#extract values from text - Q6, Q8

# %%
#save data as csv
df.to_csv("AboutCleanCleaned.csv", index = False)

# %%
#load saved data
data = pd.read_csv("AboutCleanCleaned.csv")
data.head()
# Out:
#    Duration (in seconds)         RecordedDate                     Q1  Q2   Q3  \
# 0                     51  2022-09-07 10:19:01          Emma Pedolzky  13  Yes
# 1                     91  2022-09-07 11:01:09  Norberto Alvarado III   6  Yes
# 2                    286  2022-09-07 11:02:22     Trevor Christensen   3  Yes
# 3                     59  2022-09-07 11:03:00                   Nick   9  Yes
# 4                    231  2022-09-07 11:23:38            Renee Delos  11  Yes
#
#                 Q5        Q6           Q7       Q8
# 0              Dog  May 2025  Second year  5ft 8in
# 1              Dog   05/2023  Fourth year      5'7
# 2              Dog  May 2025  Second year    5'9''
# 3  Dog,Cat,Reptile  May 2023  Fourth year        6
# 4              Dog      2024   Third year  5.66 ft

# %%
data.columns = ["duration", "date", "name", "favoriteNumber", "animalQ", "animalType", "graduationDate", "classYear", "height"]
data.head()
# Out:
#    duration                 date                   name  favoriteNumber  \
# 0        51  2022-09-07 10:19:01          Emma Pedolzky              13
# 1        91  2022-09-07 11:01:09  Norberto Alvarado III               6
# 2       286  2022-09-07 11:02:22     Trevor Christensen               3
# 3        59  2022-09-07 11:03:00                   Nick               9
# 4       231  2022-09-07 11:23:38            Renee Delos              11
#
#   animalQ       animalType graduationDate    classYear   height
# 0     Yes              Dog       May 2025  Second year  5ft 8in
# 1     Yes              Dog        05/2023  Fourth year      5'7
# 2     Yes              Dog       May 2025  Second year    5'9''
# 3     Yes  Dog,Cat,Reptile       May 2023  Fourth year        6
# 4     Yes              Dog           2024   Third year  5.66 ft

# %%
print(set(data.animalType))
# Out:
# {nan, 'Dog,Cat', 'Dog,Fish', 'Dog', 'Dog,Cat,Reptile', 'Cat'}

# %%
#one-hot-encoding
#https://scikit-learn.org/stable/modules/generated/sklearn.preprocessing.OneHotEncoder.html

dog = []
cat = []

for animals in data.animalType: #data["animalType"]
    if type(animals) == str:
        a = animals.split(',')
        #print(a)
        if "Dog" in a:
            if "Cat" in a:
                dog.append(1)
                cat.append(1)
        
            else:
                dog.append(1)
                cat.append(0)
        elif "Cat" in a:
            cat.append(1)
            dog.append(0)
        else:
            dog.append(0)
            cat.append(0)
        
    else:
        dog.append(0)
        cat.append(0)

# %%
print(len(dog))
print(len(cat))
print(len(data.animalType))
# Out:
# 24
# 24
# 24

# %%
data["dog"] = dog
data["cat"] = cat
data = data.drop(columns = ["animalType"])
data.head()
# Out:
#    duration                 date                   name  favoriteNumber  \
# 0        51  2022-09-07 10:19:01          Emma Pedolzky              13
# 1        91  2022-09-07 11:01:09  Norberto Alvarado III               6
# 2       286  2022-09-07 11:02:22     Trevor Christensen               3
# 3        59  2022-09-07 11:03:00                   Nick               9
# 4       231  2022-09-07 11:23:38            Renee Delos              11
#
#   animalQ graduationDate    classYear   height  dog  cat
# 0     Yes       May 2025  Second year  5ft 8in    1    0
# 1     Yes        05/2023  Fourth year      5'7    1    0
# 2     Yes       May 2025  Second year    5'9''    1    0
# 3     Yes       May 2023  Fourth year        6    1    1
# 4     Yes           2024   Third year  5.66 ft    1    0

# %%
data.to_csv("AboutUsCatagorized.csv")

# %%
#goal for today:
#graduation date
#sorting
#splitting and appending
#plotting

data = pd.read_csv("AboutUsCatagorized.csv")
data = data.drop(columns = "Unnamed: 0")
data.head()
# Out:
#    duration                 date                   name  favoriteNumber  \
# 0        51  2022-09-07 10:19:01          Emma Pedolzky              13
# 1        91  2022-09-07 11:01:09  Norberto Alvarado III               6
# 2       286  2022-09-07 11:02:22     Trevor Christensen               3
# 3        59  2022-09-07 11:03:00                   Nick               9
# 4       231  2022-09-07 11:23:38            Renee Delos              11
#
#   animalQ graduationDate    classYear   height  dog  cat
# 0     Yes       May 2025  Second year  5ft 8in    1    0
# 1     Yes        05/2023  Fourth year      5'7    1    0
# 2     Yes       May 2025  Second year    5'9''    1    0
# 3     Yes       May 2023  Fourth year        6    1    1
# 4     Yes           2024   Third year  5.66 ft    1    0

# %%
print(set(data.graduationDate))
# Out:
# {'2024', '2025', ' Spring 2025', '05/2023', 'May 2023', 'May 2025', '2023', '5/22/2024', '05/2024', '2022', 'May 2024', 'may 2024'}

# %%
year = []
for date in data["graduationDate"]:
    year.append(int(date[-4:])) #append and not equal
    #year.append(int('20' + date[-2:]))
    
data["graduationYear"] = year
data.head()
# Out:
#    duration                 date                   name  favoriteNumber  \
# 0        51  2022-09-07 10:19:01          Emma Pedolzky              13
# 1        91  2022-09-07 11:01:09  Norberto Alvarado III               6
# 2       286  2022-09-07 11:02:22     Trevor Christensen               3
# 3        59  2022-09-07 11:03:00                   Nick               9
# 4       231  2022-09-07 11:23:38            Renee Delos              11
#
#   animalQ graduationDate    classYear   height  dog  cat  graduationYear
# 0     Yes       May 2025  Second year  5ft 8in    1    0            2025
# 1     Yes        05/2023  Fourth year      5'7    1    0            2023
# 2     Yes       May 2025  Second year    5'9''    1    0            2025
# 3     Yes       May 2023  Fourth year        6    1    1            2023
# 4     Yes           2024   Third year  5.66 ft    1    0            2024

# %%
print(set(data.graduationYear))
print(type(data["graduationYear"][0]))
# Out:
# {2024, 2025, 2022, 2023}
# <class 'numpy.int64'>

# %%
data.sort_values(by = ["graduationYear"], ascending = True)
# Out:
#     duration                 date                   name  favoriteNumber  \
# 15        20  2022-09-08 16:39:58             ML Tlachac               6
# 1         91  2022-09-07 11:01:09  Norberto Alvarado III               6
# 3         59  2022-09-07 11:03:00                   Nick               9
# 14        36  2022-09-08 14:29:15            Jon Riordan               5
# 13        36  2022-09-08 14:19:03                   Adam               2
# 19        25  2022-09-09 06:57:45            Fadi Oumera               7
# 10        46  2022-09-08 11:28:27         Peter Sullivan              22
# 23        26  2022-09-09 07:02:55                   Luis              11
# 22        41  2022-09-09 07:00:27          Matthew Bilan              33
# 8         30  2022-09-08 09:04:27        Reese Stevenson             343
# 16        56  2022-09-08 22:35:38        Luke Lamontagne              32
# 7        187  2022-09-07 20:40:48                Griffin               7
# ...

# %%
#DO NOT COPY THIS CODE FOR CLEANING
#exaple of appending

df = data.drop(columns = ["graduationDate"])
data = pd.read_csv("AboutUsCatagorized.csv")
data = data.drop(columns = "Unnamed: 0")
adf = df.append(data)
adf
# Out:
# C:\Users\mltlachac\AppData\Local\Temp\ipykernel_21152\1800610522.py:7: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   adf = df.append(data)
#     duration                 date                   name  favoriteNumber  \
# 0         51  2022-09-07 10:19:01          Emma Pedolzky              13
# 1         91  2022-09-07 11:01:09  Norberto Alvarado III               6
# 2        286  2022-09-07 11:02:22     Trevor Christensen               3
# 3         59  2022-09-07 11:03:00                   Nick               9
# 4        231  2022-09-07 11:23:38            Renee Delos              11
# 5         75  2022-09-07 18:40:58           Katelyn Muia              44
# 6         88  2022-09-07 18:57:05      Darya Bankouskaya               4
# 7        187  2022-09-07 20:40:48                Griffin               7
# 8         30  2022-09-08 09:04:27        Reese Stevenson             343
# ...

# %%
#DO NOT COPY THIS CODE FOR CLEANING
#exaple of merging

df = data.drop(columns = ["graduationDate"])
data = pd.read_csv("AboutUsCatagorized.csv")
data = data.drop(columns = "Unnamed: 0")
adf = df.merge(data, on = "name") 
#database management, join function: inner join, outer joins
adf
# Out:
#     duration_x               date_x                   name  favoriteNumber_x  \
# 0           51  2022-09-07 10:19:01          Emma Pedolzky                13
# 1           91  2022-09-07 11:01:09  Norberto Alvarado III                 6
# 2          286  2022-09-07 11:02:22     Trevor Christensen                 3
# 3           59  2022-09-07 11:03:00                   Nick                 9
# 4          231  2022-09-07 11:23:38            Renee Delos                11
# 5           75  2022-09-07 18:40:58           Katelyn Muia                44
# 6           88  2022-09-07 18:57:05      Darya Bankouskaya                 4
# 7          187  2022-09-07 20:40:48                Griffin                 7
# 8           30  2022-09-08 09:04:27        Reese Stevenson               343
# 9           83  2022-09-08 11:22:33           Jack Sweeney                 7
# 10          46  2022-09-08 11:28:27         Peter Sullivan                22
# ...

# %%
import matplotlib.pyplot as plt
data = pd.read_csv("AboutUsCatagorized.csv")
data = data.drop(columns = "Unnamed: 0")
data.head()
# Out:
#    duration                 date                   name  favoriteNumber  \
# 0        51  2022-09-07 10:19:01          Emma Pedolzky              13
# 1        91  2022-09-07 11:01:09  Norberto Alvarado III               6
# 2       286  2022-09-07 11:02:22     Trevor Christensen               3
# 3        59  2022-09-07 11:03:00                   Nick               9
# 4       231  2022-09-07 11:23:38            Renee Delos              11
#
#   animalQ graduationDate    classYear   height  dog  cat
# 0     Yes       May 2025  Second year  5ft 8in    1    0
# 1     Yes        05/2023  Fourth year      5'7    1    0
# 2     Yes       May 2025  Second year    5'9''    1    0
# 3     Yes       May 2023  Fourth year        6    1    1
# 4     Yes           2024   Third year  5.66 ft    1    0

# %%
plt.hist(data.duration)
# Out:
# (array([10.,  6.,  5.,  0.,  0.,  0.,  1.,  1.,  0.,  1.]),
#  array([ 20. ,  46.6,  73.2,  99.8, 126.4, 153. , 179.6, 206.2, 232.8,
#         259.4, 286. ]),
#  <BarContainer object of 10 artists>)

# %%
plt.scatter(data["duration"], data["favoriteNumber"])

# %% [markdown]
# # To Finish Notebook
#
# * Clean notebook and make into a data cleaning tutorial
# * Find your name in the cleaned dataset
# * Try two different one-hot-encoding solutions
# * Finish cleaning last columns
# * Try something else from 10 minutes to pandas tutorial
# * Add comments to code
# * include one plot
#
# Due Wednesday 9/21

# %%
#assignment for quiz questions
