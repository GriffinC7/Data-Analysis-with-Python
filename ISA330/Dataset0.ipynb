# %%
import numpy as np
import pandas as pd

# %%
data = pd.read_csv("AboutUs.csv")

# %%
data.shape
# Out:
# (34, 24)

# %%
data.columns
# Out:
# Index(['StartDate', 'EndDate', 'Status', 'IPAddress', 'Progress',
#        'Duration (in seconds)', 'Finished', 'RecordedDate', 'ResponseId',
#        'RecipientLastName', 'RecipientFirstName', 'RecipientEmail',
#        'ExternalReference', 'LocationLatitude', 'LocationLongitude',
#        'DistributionChannel', 'UserLanguage', 'Q1', 'Q2', 'Q3', 'Q5', 'Q6',
#        'Q7', 'Q8'],
#       dtype='object')

# %%
data.head()
# Out:
#                                            StartDate  \
# 0                                         Start Date
# 1  {"ImportId":"startDate","timeZone":"America/De...
# 2                                      9/7/2022 9:56
# 3                                     9/7/2022 10:00
# 4                                     9/7/2022 10:01
#
#                                              EndDate                 Status  \
# 0                                           End Date          Response Type
# 1  {"ImportId":"endDate","timeZone":"America/Denv...  {"ImportId":"status"}
# 2                                      9/7/2022 9:56         Survey Preview
# 3                                     9/7/2022 10:00             IP Address
# 4                                     9/7/2022 10:01             IP Address
#
#                   IPAddress                 Progress    Duration (in seconds)  \
# 0                IP Address                 Progress    Duration (in seconds)
# ...

# %%
data.tail()
# Out:
#         StartDate        EndDate      Status        IPAddress Progress  \
# 29  9/9/2022 6:57  9/9/2022 6:57  IP Address  192.135.181.229      100
# 30  9/9/2022 6:56  9/9/2022 6:57  IP Address  192.135.181.228      100
# 31  9/9/2022 6:59  9/9/2022 6:59  IP Address  192.135.181.239      100
# 32  9/9/2022 6:59  9/9/2022 7:00  IP Address  192.135.181.236      100
# 33  9/9/2022 7:02  9/9/2022 7:02  IP Address  192.135.181.228      100
#
#    Duration (in seconds) Finished   RecordedDate         ResponseId  \
# 29                    25     TRUE  9/9/2022 6:57  R_vq4Q29b4K6w6meR
# 30                    69     TRUE  9/9/2022 6:57  R_vNzGUlW6whj8phL
# 31                    22     TRUE  9/9/2022 6:59  R_2rOrJvxYlDcVh4U
# 32                    41     TRUE  9/9/2022 7:00  R_2f6Tis0LwSIHpCR
# 33                    26     TRUE  9/9/2022 7:02  R_sdHM6980d7pLXO1
#
#    RecipientLastName  ... LocationLongitude DistributionChannel UserLanguage  \
# ...

# %%
data.index
# Out:
# RangeIndex(start=0, stop=34, step=1)

# %%
data.to_numpy()
# Out:
# array([['Start Date', 'End Date', 'Response Type', 'IP Address',
#         'Progress', 'Duration (in seconds)', 'Finished', 'Recorded Date',
#         'Response ID', 'Recipient Last Name', 'Recipient First Name',
#         'Recipient Email', 'External Data Reference',
#         'Location Latitude', 'Location Longitude',
#         'Distribution Channel', 'User Language', 'Name',
#         'Favorite Number', 'Pet?', 'Type of Pet?', 'Graduation Date?',
#         'Class Year', 'Height in Feet?'],
#        ['{"ImportId":"startDate","timeZone":"America/Denver"}',
#         '{"ImportId":"endDate","timeZone":"America/Denver"}',
#         '{"ImportId":"status"}', '{"ImportId":"ipAddress"}',
#         '{"ImportId":"progress"}', '{"ImportId":"duration"}',
#         '{"ImportId":"finished"}',
#         '{"ImportId":"recordedDate","timeZone":"America/Denver"}',
#         '{"ImportId":"_recordId"}', '{"ImportId":"recipientLastName"}',
#         '{"ImportId":"recipientFirstName"}',
# ...

# %%
data.describe()
# Out:
#             StartDate        EndDate      Status        IPAddress Progress  \
# count              34             34          34               33       34
# unique             30             28           5               17        3
# top     9/9/2022 6:59  9/9/2022 6:57  IP Address  192.135.181.232      100
# freq                2              3          30                4       32
#
#        Duration (in seconds) Finished   RecordedDate   ResponseId  \
# count                     34       34             34           34
# unique                    29        3             29           34
# top                       36     TRUE  9/9/2022 6:57  Response ID
# freq                       3       32              3            1
#
#           RecipientLastName  ... LocationLongitude DistributionChannel  \
# count                     2  ...                34                  34
# unique                    2  ...                 7                   4
# ...

# %%
data.columns
# Out:
# Index(['StartDate', 'EndDate', 'Status', 'IPAddress', 'Progress',
#        'Duration (in seconds)', 'Finished', 'RecordedDate', 'ResponseId',
#        'RecipientLastName', 'RecipientFirstName', 'RecipientEmail',
#        'ExternalReference', 'LocationLatitude', 'LocationLongitude',
#        'DistributionChannel', 'UserLanguage', 'Q1', 'Q2', 'Q3', 'Q5', 'Q6',
#        'Q7', 'Q8'],
#       dtype='object')

# %%
data.head()
# Out:
#                                            StartDate  \
# 0                                         Start Date
# 1  {"ImportId":"startDate","timeZone":"America/De...
# 2                                      9/7/2022 9:56
# 3                                     9/7/2022 10:00
# 4                                     9/7/2022 10:01
#
#                                              EndDate                 Status  \
# 0                                           End Date          Response Type
# 1  {"ImportId":"endDate","timeZone":"America/Denv...  {"ImportId":"status"}
# 2                                      9/7/2022 9:56         Survey Preview
# 3                                     9/7/2022 10:00             IP Address
# 4                                     9/7/2022 10:01             IP Address
#
#                   IPAddress                 Progress    Duration (in seconds)  \
# 0                IP Address                 Progress    Duration (in seconds)
# ...

# %%
data.sort_values(by="Q6", ascending = False)
# Out:
#                                             StartDate  \
# 1   {"ImportId":"startDate","timeZone":"America/De...
# 5                                      9/7/2022 10:17
# 6                                      9/7/2022 10:18
# 8                                      9/7/2022 10:57
# 14                                     9/7/2022 20:23
# 12                                     9/7/2022 18:39
# 26                                     9/8/2022 22:34
# 15                                     9/7/2022 20:37
# 16                                      9/8/2022 9:03
# 22                                     9/8/2022 14:28
# 7                                      9/7/2022 10:59
# 10                                     9/7/2022 11:02
# 21                                     9/8/2022 14:18
# 29                                      9/9/2022 6:57
# 0                                          Start Date
# 13                                     9/7/2022 18:55
# ...

# %%
print(list(data["Q5"]))
# Out:
# ['Type of Pet?', '{"ImportId":"QID5"}', nan, nan, nan, 'Dog', 'Dog', 'Dog', 'Dog', nan, 'Dog,Cat,Reptile', 'Dog', 'Dog', 'Dog', nan, nan, 'Dog,Cat', 'Dog', 'Dog', 'Dog', 'Dog,Cat', 'Dog', 'Dog', 'Dog,Fish', 'Fish', 'Dog,Fish', 'Dog', nan, 'Cat', nan, 'Dog', 'Dog', 'Dog', nan]

# %%
data[9:11]
# Out:
#          StartDate         EndDate      Status        IPAddress Progress  \
# 9   9/7/2022 11:02  9/7/2022 11:02  IP Address  192.135.181.226      100
# 10  9/7/2022 11:02  9/7/2022 11:02  IP Address   174.242.137.12      100
#
#    Duration (in seconds) Finished    RecordedDate         ResponseId  \
# 9                      6     TRUE  9/7/2022 11:02  R_3h4L8hnUrlBhepi
# 10                    59     TRUE  9/7/2022 11:03  R_0wS9uSXw91RR4DT
#
#    RecipientLastName  ... LocationLongitude DistributionChannel UserLanguage  \
# 9                NaN  ...          -71.5165           anonymous           EN
# 10               NaN  ...           -71.408           anonymous           EN
#
#       Q1   Q2   Q3               Q5      Q6           Q7   Q8
# 9    NaN  NaN  NaN              NaN     NaN          NaN  NaN
# 10  Nick    9  Yes  Dog,Cat,Reptile  May-23  Fourth year    6
#
# [2 rows x 24 columns]

# %%
data["Q1"]
# Out:
# 0                         Name
# 1     {"ImportId":"QID1_TEXT"}
# 2                      Testing
# 3                     Testing2
# 4                     Testing3
# 5               Emma Pedolzky
# 6              Emma Pedolzky
# 7        Norberto Alvarado III
# 8           Trevor Christensen
# 9                          NaN
# 10                        Nick
# 11                 Renee Delos
# 12                Katelyn Muia
# 13           Darya Bankouskaya
# 14             Ganesh Thammana
# 15                     Griffin
# 16            Reese Stevenson
# 17                Jack Sweeney
# 18              Peter Sullivan
# 19         Ian James Carpenter
# 20                  Luke Walsh
# 21                        Adam
# 22                 Jon Riordan
# 23                  ML Tlachac
# 24                  ML Tlachac
# 25                  ML Tlachac
# 26             Luke Lamontagne
# 27             Ganesh Thammana
# 28                      Thomas
# 29                 Fadi Oumera
# ...

# %%
data["Q1"][15]
# Out:
# 'Griffin'

# %%
data.iloc[15,17]
# Out:
# 'Griffin'
